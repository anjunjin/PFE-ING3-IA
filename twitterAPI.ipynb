# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import tweepy as tw
import pandas as pd

# %%
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# Send a Tweet

# %%
# Post a tweet from Python
api.update_status("xxx.")

# %% [markdown]
# Search Twitter for Tweets

# %%
search_words = "#xxx"
date_since = "xxx-xxx-xxx"

# item(n) will return n of the most recent tweets
n=5
tweets = tw.Cursor(api.search,
                   q=search_words,
                   lang="en",
                   since=date_since).items(n)

# ? type
# <tweepy.cursor.ItemIterator at 0x7fafc296e400>
tweets

# Iterate and print tweets
for tweet in tweets:
  print(tweet.text)

# Collect a list of tweets
[tweet.text for tweet in tweets]

# %% [markdown]
# To keep or Remove Retweets

# %%
new_search = search_word + " -filler:retweets"
new_search

# peut devenir un def
# item(n) will return n of the most recent tweets
n=5
tweets = tw.Cursor(api.search,
                   q=search_words,
                   lang="en",
                   since=date_since).items(n)
[tweet.text for tweet in tweets]

# %% [markdown]
# Who is Tweeting About Wildfires?

# %%
n=5
tweets = tw.Cursor(api.search,
                   q=search_words,
                   lang="en",
                   since=date_since).items(n)

user_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
user_locs

# %% [markdown]
# Create a Pandas Dataframe from A List of Tweet Data

# %%
# ? "" ''
tweet_text = pd.DataFrame(data=user_locs,
                          columns=['user', "location"])
tweet_text

# %% [markdown]
# Customizing Twitter Queries

# %%
new_search = "climate+change -filter:retweets"
tweets = tw.Cursor(api.search,
                   q=search_words,
                   lang="en",
                   since='xxx-xxx-xxx').items(n)

all_tweets = [tweet.text for tweet in tweets]
all_tweets[:5]
